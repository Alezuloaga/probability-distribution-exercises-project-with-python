# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)
size = 10
prob = 0.2

data = rbinom(2000, size = 10, prob = 0.2)
pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# ### Distribución Normal

# %%
# TODO

from scipy.stats import norm
import numpy as np

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dnorm(x, mean = 0 , std = 1 ):
    
    result = norm.pdf(x = x , loc = mean , scale =std )

    return result

def pnorm(p, mean , std) :
  
    result = norm.cdf(x = p , loc = mean , scale =std)

    return result

def qnorm(p , mean , std):
    
    result = norm.ppf(q = p, loc = mean , scale =std)

    return result

def rnorm(n, mean , std):
    
    result = norm.rvs(size = n,  loc = mean , scale =std)

    return result

np.random.seed(42)
import matplotlib.pyplot as plt


fig, axis = plt.subplots(3, 1, figsize=(8, 10))


data = np.arange(-5, 5, 0.01)

pmf = dnorm(data, 0, 1)
cdf = pnorm(data, 0, 1)
ppf = qnorm(data, 0, 1)


axis[0].plot(data, pmf, "g-") 
axis[1].plot(data, cdf, "r-") 
axis[2].plot(data, ppf, "b-") 

plt.tight_layout()
plt.show()






print(f"Probability that a Normal (0,1) takes the value 2: {dnorm(2, 0, 1)}")
print(f"Probability that a Normal (0,1) will take a value less than 2: {pnorm(2,0,1)}")
print(f"Which value of a Normal (10, 0.2) has a cumulative probability of 0.9? {qnorm(0.9, 0 ,1) }")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rnorm(2000,0,1)}")
# Out:
# Probability that a Normal (0,1) takes the value 2: 0.05399096651318806
# Probability that a Normal (0,1) will take a value less than 2: 0.9772498680518208
# Which value of a Normal (10, 0.2) has a cumulative probability of 0.9? 1.2815515655446004
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [ 0.49671415 -0.1382643   0.64768854 ... -0.88187465 -0.16306696
#  -0.74490264]

# %% [markdown]
# ### Distribución uniforme

# %%
from scipy.stats import uniform

def dunif(x, low = 0, high = 1):
  
    result = uniform.pdf(x, loc = low, scale = (high - low))

    return result

def punif(q, low = 0, high = 1):
  
    result = uniform.cdf(q, loc = low, scale = (high - low))

    return result

def qunif(p, low = 0, high = 1):
  
    result = uniform.ppf(p, loc = low, scale = (high - low))

    return result

def runif(n, low = 0, high = 1):
    
    result = uniform.rvs(loc = low, scale = (high - low), size = n)

    return result

np.random.seed(42)

fig, axis = plt.subplots(3, 1, figsize=(8, 10))


data = np.arange(-5, 5, 0.01)

pmf = dunif(data, 0, 1)
cdf = punif(data, 0, 1)
ppf = qunif(data, 0, 1)


axis[0].plot(data, pmf, "b-") 
axis[1].plot(data, cdf, "g-") 
axis[2].plot(data, ppf, "r-") 

plt.tight_layout()
plt.show()


print(f"Probability that a Uniform (0,1) takes the value 2: {dunif(2, 0, 1)}")
print(f"Probability that a Uniform (0,1) will take a value less than 2: {punif(2,0,1)}")
print(f"Which value of a Uniform (10, 0.2) has a cumulative probability of 0.9? {qunif(0.9, 0 ,1) }")
print(f"Generate 2000 Uniform values from a Binomial(10, 0.2) distribution: {runif(2000,0,1)}")
# Out:
# Probability that a Uniform (0,1) takes the value 2: 0.0
# Probability that a Uniform (0,1) will take a value less than 2: 1.0
# Which value of a Uniform (10, 0.2) has a cumulative probability of 0.9? 0.9
# Generate 2000 Uniform values from a Binomial(10, 0.2) distribution: [0.37454012 0.95071431 0.73199394 ... 0.06895802 0.05705472 0.28218707]
